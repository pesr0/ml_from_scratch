# %%
from kmeans_model_class import MyKMeansModel
from sklearn.datasets import make_blobs

import numpy as np

# %%
np.random.seed(42)

X, _ = make_blobs(
    centers=3, n_samples=500, n_features=2, shuffle=True, random_state=40
)
print(X.shape)
# Out:
# (500, 2)

# %%
model = MyKMeansModel(K=3, max_iters=20, plot_iters=True)
results = model.predict(X)
